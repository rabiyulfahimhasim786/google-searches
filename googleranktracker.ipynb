# %% [markdown]
# <a href="https://colab.research.google.com/github/rabiyulfahimhasim786/google-searches/blob/main/googleranktracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://practicaldatascience.co.uk/data-science/how-to-create-a-google-rank-checker-tool-using-python
#https://practicaldatascience.co.uk/data-science/how-to-scrape-google-search-results-using-python

# %%
# !pip3 install --upgrade ecommercetools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ecommercetools
#   Downloading ecommercetools-0.42.3-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 3.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (1.21.6)
# Collecting gapandas
#   Downloading gapandas-1.0-py3-none-any.whl (12 kB)
# Collecting pycausalimpact
#   Downloading pycausalimpact-0.1.1-py2.py3-none-any.whl (30 kB)
# Collecting lifetimes
#   Downloading Lifetimes-0.11.3-py3-none-any.whl (584 kB)
#      |████████████████████████████████| 584 kB 15.1 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (1.12.1+cu113)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (2.23.0)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (1.3.5)
# Collecting transformers
#   Downloading transformers-4.21.2-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 39.2 MB/s
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: httplib2>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (0.17.4)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.7/dist-packages (from gapandas->ecommercetools) (1.12.11)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from gapandas->ecommercetools) (4.1.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (3.0.1)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (1.35.0)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (1.31.6)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (0.0.4)
# Requirement already satisfied: six<2dev,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (1.15.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (21.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (1.56.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (2022.2.1)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (3.17.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (2022.6.15)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from lifetimes->ecommercetools) (1.7.3)
# Requirement already satisfied: autograd>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from lifetimes->ecommercetools) (1.4)
# Requirement already satisfied: dill>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from lifetimes->ecommercetools) (0.3.5.1)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.2.0->lifetimes->ecommercetools) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ecommercetools) (2.8.2)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.7/dist-packages (from pycausalimpact->ecommercetools) (3.2.2)
# Requirement already satisfied: statsmodels>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from pycausalimpact->ecommercetools) (0.12.2)
# Requirement already satisfied: jinja2>=2.10 in /usr/local/lib/python3.7/dist-packages (from pycausalimpact->ecommercetools) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.10->pycausalimpact->ecommercetools) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.2.3->pycausalimpact->ecommercetools) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.2.3->pycausalimpact->ecommercetools) (1.4.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=2.2.3->pycausalimpact->ecommercetools) (4.1.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.11.0->pycausalimpact->ecommercetools) (0.5.2)
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Collecting w3lib
#   Downloading w3lib-2.0.1-py3-none-any.whl (20 kB)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 998 kB/s
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->ecommercetools) (0.0.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (1.4.4)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (4.12.0)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (112 kB)
#      |████████████████████████████████| 112 kB 31.4 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 62.7 MB/s
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (4.64.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->ecommercetools) (3.8.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->ecommercetools) (4.6.3)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->ecommercetools) (4.9.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->ecommercetools) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->ecommercetools) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->ecommercetools) (3.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (3.8.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 56.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 46.1 MB/s
# Building wheels for collected packages: fake-useragent, parse, sklearn
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=19dff2f74479a68f5d45bdea0fdedb02a3af85019bc6ecba22ed93dbf2436da4
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=d6c4c9452bb787139ecccd2ab9c447594a194e3302a83f69d8fa5e6b216405de
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=e5e13dde872621bff684a3f491a5397431ab84397ff6a3b44c3826a68c1a09d5
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built fake-useragent parse sklearn
# Installing collected packages: urllib3, websockets, pyee, cssselect, w3lib, tokenizers, pyquery, pyppeteer, parse, huggingface-hub, fake-useragent, transformers, sklearn, requests-html, pycausalimpact, lifetimes, gapandas, ecommercetools
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed cssselect-1.1.0 ecommercetools-0.42.3 fake-useragent-0.1.11 gapandas-1.0 huggingface-hub-0.9.1 lifetimes-0.11.3 parse-1.19.0 pycausalimpact-0.1.1 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 requests-html-0.10.0 sklearn-0.0 tokenizers-0.12.1 transformers-4.21.2 urllib3-1.25.11 w3lib-2.0.1 websockets-10.3

# %%
import time
import datetime
import pandas as pd
from ecommercetools import seo

# %%
df = seo.get_serps("contractual churn model", pages=5)

# %%
df.head(10)
# Out:
#    position                                              title  \
# 0         1  How to create a contractual churn model in sci...
# 1         2  Modeling Churn and Usage Behavior in Contractu...
# 2         3  A Joint Model of Usage and Churn in Contractua...
# 3         4  Customer Churn Prediction in B2B Non-Contractu...
# 4         5  How to Define Churn in a Non-Contractual Busin...
# 5         6                           Churn Prediction | KNIME
# 6         7  A Joint Model of Usage and Churn in Contractua...
# 7         8  What is Customer Churn Modeling? Why is it val...
# 8         9  Customer Churn Prediction Approaches For B2B a...
# 9        10                     Customer churn models - ShopUp
#
#                                                 link  \
# 0  https://practicaldatascience.co.uk/machine-lea...
# 1  https://www0.gsb.columbia.edu/mygsb/faculty/re...
# 2  https://www.hbs.edu/ris/download.aspx?name=asc...
# 3      https://www.mdpi.com/2076-3417/12/10/5001/pdf
# 4  https://forecast.global/insight/how-to-define-...
# 5  https://www.knime.com/knime-applications/churn...
# 6  https://www.researchgate.net/publication/22815...
# 7  https://www.kdnuggets.com/2017/03/datascience-...
# 8  https://www.genroe.com/blog/customer-churn-pre...
# 9              https://shopup.me/model/churn-models/
#
#                                                 text          bold
# 0
# 1  by E Ascarza · 2009 · Cited by 4 — In contrast...  churn models
# 2  by E Ascarza · 2013 · Cited by 119 — We propos...         model
# 3  by M Mirkovic · 2022 — nies that operate in no...   contractual
# 4  Feb 25, 2020 — Customer churn in a contractual...         churn
# 5  The contract data contains, among various attr...      contract
# 6  Jul 5, 2022 — While a number of researchers ha...      modeling
# 7  Mar 1, 2017 — In its simplest form, churn rate...         churn
# 8  Since then the number of subscription style bu...        models
# 9  Building a predictive churn model helps you ma...   churn model

# %%
def get_top_rank(df, domain):
  data = df[df['link'].str.startswith(domain)].head(1).to_dict('records')
    
  if len(data) > 0:
    return data[0]
  else:
    return

# %%
def rank_checker(keywords, domain, sleep=2, verbose=False):
  df = pd.DataFrame(columns=['keyword', 'date', 'position', 'title', 'link', 'text'])
  for keyword in keywords:
    if verbose:
      print('Fetching:', keyword)
            
    data = get_top_rank(seo.get_serps(keyword, pages=5), domain)
    time.sleep(2)

    if data:
      data['keyword'] = keyword
    else:
      data = {'keyword': keyword, 'position': '', 'title': '', 'link': '', 'text': ''}

    date = datetime.datetime.now()
    data['date'] = date.strftime('%Y-%m-%d')

    df = df.append(data, ignore_index=True)
  return df

# %%
keywords = [
    'contractual churn model', 
    'non contractual churn model', 
    'product matching model',
    'marketing mix model',
    'purchase intention model',
    'inventory classification model',
    'rfm model',
    'causal impact model',
    'product classification model', 
    'learning to rank model',
    'customer segmentation model',
    'bg/nbd model',
    'abc xyz inventory classification model', 
    'abc inventory classification model',
    'isolation forest model',
    'response model',
    'product attribute extraction model',
    'next product to buy model',
    'xgboost classification model',
    'scikit learn linear regression model'
]

# %%
domain = 'https://practicaldatascience.co.uk'
df = rank_checker(keywords, domain, sleep=10, verbose=True)
# Out:
# Fetching: contractual churn model
# Fetching: non contractual churn model
# Fetching: product matching model
# Fetching: marketing mix model
# Fetching: purchase intention model
# Fetching: inventory classification model
# Fetching: rfm model
# Fetching: causal impact model
# Fetching: product classification model
# Fetching: learning to rank model
# Fetching: customer segmentation model
# Fetching: bg/nbd model
# Fetching: abc xyz inventory classification model
# Fetching: abc inventory classification model
# Fetching: isolation forest model
# Fetching: response model
# Fetching: product attribute extraction model
# Fetching: next product to buy model
# Fetching: xgboost classification model
# Fetching: scikit learn linear regression model

# %%
df
# Out:
#                                    keyword        date position  \
# 0                  contractual churn model  2022-08-27        1
# 1              non contractual churn model  2022-08-27        2
# 2                   product matching model  2022-08-27        2
# 3                      marketing mix model  2022-08-27
# 4                 purchase intention model  2022-08-27       41
# 5           inventory classification model  2022-08-27        5
# 6                                rfm model  2022-08-27       36
# 7                      causal impact model  2022-08-27        8
# 8             product classification model  2022-08-27        2
# 9                   learning to rank model  2022-08-27        6
# 10             customer segmentation model  2022-08-27       46
# 11                            bg/nbd model  2022-08-27        3
# 12  abc xyz inventory classification model  2022-08-27        3
# 13      abc inventory classification model  2022-08-27        6
# 14                  isolation forest model  2022-08-27       15
# 15                          response model  2022-08-27       10
# 16      product attribute extraction model  2022-08-27        1
# 17               next product to buy model  2022-08-27        1
# 18            xgboost classification model  2022-08-27        2
# 19    scikit learn linear regression model  2022-08-27       27
#
#                                                 title  \
# 0   How to create a contractual churn model in sci...
# 1   How to create a non-contractual churn model fo...
# 2   How to create a product matching model using X...
# 3
# 4   How to create an ecommerce purchase intention ...
# 5   How to create an ABC inventory classification ...
# 6   A quick guide to the RFM model for data scient...
# 7   How to infer the effects of marketing using th...
# 8   How to create a Naive Bayes product classifica...
# 9            A quick guide to Learning to Rank models
# 10  A quick guide to customer segmentation for dat...
# 11  How to calculate CLV using BG/NBD and Gamma-Gamma
# 12  How to create an ABC XYZ inventory classificat...
# 13  How to create an ABC inventory classification ...
# 14  How to use the Isolation Forest model for outl...
# 15  How to create a response model to improve outb...
# 16  A quick guide to Product Attribute Extraction ...
# 17        A quick guide to Next-Product-To-Buy models
# 18  How to create a classification model ... - Pra...
# 19  How to create a linear regression model using ...
#
#                                                  link  \
# 0   https://practicaldatascience.co.uk/machine-lea...
# 1   https://practicaldatascience.co.uk/machine-lea...
# 2   https://practicaldatascience.co.uk/machine-lea...
# 3
# 4   https://practicaldatascience.co.uk/machine-lea...
# 5   https://practicaldatascience.co.uk/data-scienc...
# 6   https://practicaldatascience.co.uk/data-scienc...
# 7   https://practicaldatascience.co.uk/machine-lea...
# 8   https://practicaldatascience.co.uk/machine-lea...
# 9   https://practicaldatascience.co.uk/machine-lea...
# 10  https://practicaldatascience.co.uk/data-scienc...
# 11  https://practicaldatascience.co.uk/data-scienc...
# 12  https://practicaldatascience.co.uk/data-scienc...
# 13  https://practicaldatascience.co.uk/data-scienc...
# 14  https://practicaldatascience.co.uk/machine-lea...
# 15  https://practicaldatascience.co.uk/machine-lea...
# 16  https://practicaldatascience.co.uk/machine-lea...
# 17  https://practicaldatascience.co.uk/machine-lea...
# 18  https://practicaldatascience.co.uk/machine-lea...
# 19  https://practicaldatascience.co.uk/machine-lea...
#
#                                                  text  \
# 0
# 1   Churn modeling requires the use of raw non-dis...
# 2   Mar 13, 2021 — Product matching algorithms fin...
# 3
# 4   May 29, 2021 — Ecommerce purchase intention mo...
# 5   ABC inventory classification is based on the P...
# 6   RFM stands for Recency (R), Frequency (F), and...
# 7   Aug 12, 2021 — The Causal Impact model lets yo...
# 8   Mar 13, 2021 — Product classification models t...
# 9   Learning to Rank, or machine-learned ranking (...
# 10  Customer segmentation is the process of using ...
# 11  Mar 14, 2021 — Calculating Customer Lifetime V...
# 12  The ABC XYZ inventory classification model is ...
# 13  ABC inventory classification has been one of t...
# 14  As the name suggests, the Isolation Forest is ...
# 15  The predictive response models used to help id...
# 16  Learn why ecommerce retailers and marketplaces...
# 17  A Next-Product-To-Buy (or NPTB) model is desig...
# 18  As we're building a classification model, it's...
# 19  Want to get started with sklearn linear regres...
#
#                                       bold
# 0
# 1                           churn modeling
# 2                         product matching
# 3                                      NaN
# 4                purchase intention models
# 5                 inventory classification
# 6                                      rfm
# 7                      causal impact model
# 8            product classification models
# 9                         learning to rank
# 10                   customer segmentation
# 11                                      bg
# 12  abc xyz inventory classification model
# 13            abc inventory classification
# 14                        isolation forest
# 15                         response models
# 16            product attribute extraction
# 17                                    next
# 18                    classification model
# 19               sklearn linear regression
